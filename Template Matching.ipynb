# %%
# %config IPCompleter.greedy=True

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/home/karen/Documents/Datasets/OpenCV/opencv/samples/data/messi5.jpg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

template = cv2.imread('/home/karen/Documents/Datasets/OpenCV/opencv/samples/data/messi_face.jpg', 0)
w, h = template.shape[::-1]

res = cv2.matchTemplate(gray_img, template, cv2.TM_CCOEFF_NORMED)
# print(res)

threshold = 0.95;
loc = np.where(res >= threshold)
print(loc)

for pt in zip(*loc[::-1]):
    cv2.rectangle(img, pt, (pt[0] + w, pt[1] + h), (0, 0, 255), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (array([56]), array([203]))
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
#
# QObject::moveToThread: Current thread (0x2277e50) is not the object's thread (0x1f09390).
# Cannot move to target thread (0x2277e50)
