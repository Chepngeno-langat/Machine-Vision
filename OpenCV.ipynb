# %%
import cv2

url = 'http://192.168.100.17:4747/video'
cap = cv2.VideoCapture(1)

while(True):
    ret, frame = cap.read()
    
#     if not ret:
#         # Break the loop if there are no more frames to read
#         break
    
    cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame', frame)
    
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# ...

# %%
def click_event(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
#         cv2.circle(img, (x, y), 3, (0, 0, 255), -1)
#         points.append((x, y))
        
#         if len(points) >= 2:
#             cv2.line(img2, points[-1], points[-2], (255, 0, 0), 5)
        print(x, ', ', y)
        font = cv2.FONT_HERSHEY_SIMPLEX
        strXY = str(x) + ', ' + str(y)
        cv2.putText(img, strXY, (x, y), font, .5, (255, 0, 0), 2)
        
    
        cv2.imshow('image', img)
    
        
#     if event == cv2.EVENT_RBUTTONDOWN:
#         blue = img[y, x, 0]
#         green = img[y, x, 1]
#         red = img[y, x, 2]
#         font = cv2.FONT_HERSHEY_SIMPLEX
#         strBGR = str(blue) + ', ' + str(green)+ ', ' + str(red)
#         cv2.putText(img, strXY, (x, y), font, .5, (255, 255, 0), 2)
#         cv2.imshow('image', img)


img = cv2.imread('/home/karen/Documents/Datasets/OpenCV/opencv/samples/data/lena.jpg', 1)
cv2.imshow('image', img)

points = []

cv2.setMouseCallback('image', click_event)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# ...

# %%
img2 = cv2.imread('/home/karen/Documents/Datasets/OpenCV/opencv/samples/data/messi5.jpg', 1)

ball = img2[280:340, 330:390]
img2[273:333, 100:160] = ball

cv2.imshow('image', img2)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# ...

# %%
img3 = cv2.imread('/home/karen/Documents/Datasets/OpenCV/opencv/samples/data/opencv-logo.png', 1)

img2 = cv2.resize(img2, (512, 512))
img3 = cv2.resize(img3, (512, 512))

dst = cv2.add(img2, img3)

cv2.imshow('image', dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# ...

# %%
dst = cv2.addWeighted(img2, .8, img3, .1, 0)

cv2.imshow('image', dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# ...

# %%
import numpy as np

img1 = np.zeros((250, 512, 3), np.uint8)
img1 = cv2.rectangle(img1, (200, 0), (300, 100), (255, 255, 255), -1)

img2= np.zeros((250, 512, 3), np.uint8)

bitAnd = cv2.bitwise_and(img2, img1)

cv2.imshow('image1', img1)
cv2.imshow('image2', img2)
cv2.imshow('bitAnd', bitAnd)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# QObject::moveToThread: Current thread (0x2688e60) is not the object's thread (0x2a7cc70).
# Cannot move to target thread (0x2688e60)
#
# ...

# %%
img = np.zeros((300, 512, 3), np.uint8)
cv2.namedWindow('image')

def nothing(x):
    print(x)

cv2.createTrackbar('B', 'image', 0, 255, nothing)
cv2.createTrackbar('G', 'image', 0, 255, nothing)
cv2.createTrackbar('R', 'image', 0, 255, nothing)

switch = '0 : OFF\n 1 : ON'
cv2.createTrackbar(switch, 'image', 0, 1, nothing)

while(1):
    cv2.imshow('image', img)
    k = cv2.waitKey(1) & 0XFF
    if k == 27:
        break
    
    b = cv2.getTrackbarPos('B', 'image')
    g = cv2.getTrackbarPos('G', 'image')
    r = cv2.getTrackbarPos('R', 'image')
    s = cv2.getTrackbarPos(switch, 'image')
    
    if s == 0:
        img[:] = 0
    else:
        img[:] = [b, g, r]
cv2.destroyAllWindows()
